# %% [markdown]
# ## Estimation Example

# %% [markdown]
# In this document we&rsquo;ll work through a simple approach to estimating
# Constant Frisch Elasticity (CFE) demand systems.
#
# There are two prerequisites; the first is the `CFEDemands` python
# module.  You may have this already, but if not it  can be installed with a simple:

# %%
# !pip install -r requirements.txt
# Out:
# Collecting CFEDemands>=0.6.3.dev0 (from -r requirements.txt (line 5))
#   Using cached cfedemands-0.6.4.dev0-py2.py3-none-any.whl.metadata (1.6 kB)
# Collecting ConsumerDemands>=0.4.3.dev0 (from -r requirements.txt (line 7))
#   Using cached ConsumerDemands-0.4.3.dev0-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: matplotlib>=3.3.4 in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 10)) (3.10.1)
# Requirement already satisfied: numpy>=1.21.5 in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 14)) (2.2.4)
# Requirement already satisfied: pandas>=1.3.5 in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 20)) (2.2.3)
# Requirement already satisfied: plotly>=5.1.0 in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 23)) (6.0.1)
# Collecting eep153_tools>=0.11 (from -r requirements.txt (line 25))
#   Using cached eep153_tools-0.12.4-py2.py3-none-any.whl.metadata (363 bytes)
# Collecting python-gnupg (from -r requirements.txt (line 26))
#   Using cached python_gnupg-0.5.4-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting gspread_pandas>=3.3 (from -r requirements.txt (line 28))
#   Using cached gspread_pandas-3.3.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: scikit-learn in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 30)) (1.6.0)
# Requirement already satisfied: xarray in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 31)) (2025.1.1)
# Requirement already satisfied: scipy>=1.7.3 in /srv/conda/lib/python3.11/site-packages (from CFEDemands>=0.6.3.dev0->-r requirements.txt (line 5)) (1.14.1)
# Requirement already satisfied: importlib_metadata>=6.7.0 in /srv/conda/lib/python3.11/site-packages (from CFEDemands>=0.6.3.dev0->-r requirements.txt (line 5)) (8.6.1)
# Collecting fsspec (from CFEDemands>=0.6.3.dev0->-r requirements.txt (line 5))
#   Using cached fsspec-2025.3.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (24.2)
# Requirement already satisfied: pillow>=8 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/lib/python3.11/site-packages (from pandas>=1.3.5->-r requirements.txt (line 20)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/lib/python3.11/site-packages (from pandas>=1.3.5->-r requirements.txt (line 20)) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in /srv/conda/lib/python3.11/site-packages (from plotly>=5.1.0->-r requirements.txt (line 23)) (1.33.0)
# Requirement already satisfied: gspread<6,>=5.0.0 in /srv/conda/lib/python3.11/site-packages (from gspread_pandas>=3.3->-r requirements.txt (line 28)) (5.12.4)
# Requirement already satisfied: decorator in /srv/conda/lib/python3.11/site-packages (from gspread_pandas>=3.3->-r requirements.txt (line 28)) (5.1.1)
# Requirement already satisfied: google-auth in /srv/conda/lib/python3.11/site-packages (from gspread_pandas>=3.3->-r requirements.txt (line 28)) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib in /srv/conda/lib/python3.11/site-packages (from gspread_pandas>=3.3->-r requirements.txt (line 28)) (1.2.1)
# Requirement already satisfied: joblib>=1.2.0 in /srv/conda/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 30)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /srv/conda/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 30)) (3.6.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /srv/conda/lib/python3.11/site-packages (from google-auth->gspread_pandas>=3.3->-r requirements.txt (line 28)) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /srv/conda/lib/python3.11/site-packages (from google-auth->gspread_pandas>=3.3->-r requirements.txt (line 28)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /srv/conda/lib/python3.11/site-packages (from google-auth->gspread_pandas>=3.3->-r requirements.txt (line 28)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /srv/conda/lib/python3.11/site-packages (from google-auth-oauthlib->gspread_pandas>=3.3->-r requirements.txt (line 28)) (2.0.0)
# Requirement already satisfied: zipp>=3.20 in /srv/conda/lib/python3.11/site-packages (from importlib_metadata>=6.7.0->CFEDemands>=0.6.3.dev0->-r requirements.txt (line 5)) (3.21.0)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->-r requirements.txt (line 10)) (1.17.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /srv/conda/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth->gspread_pandas>=3.3->-r requirements.txt (line 28)) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /srv/conda/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gspread_pandas>=3.3->-r requirements.txt (line 28)) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /srv/conda/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gspread_pandas>=3.3->-r requirements.txt (line 28)) (2.32.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/lib/python3.11/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib->gspread_pandas>=3.3->-r requirements.txt (line 28)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.11/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib->gspread_pandas>=3.3->-r requirements.txt (line 28)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.11/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib->gspread_pandas>=3.3->-r requirements.txt (line 28)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.11/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib->gspread_pandas>=3.3->-r requirements.txt (line 28)) (2025.1.31)
# Using cached cfedemands-0.6.4.dev0-py2.py3-none-any.whl (45 kB)
# Using cached ConsumerDemands-0.4.3.dev0-py2.py3-none-any.whl (12 kB)
# Using cached eep153_tools-0.12.4-py2.py3-none-any.whl (4.9 kB)
# Using cached python_gnupg-0.5.4-py2.py3-none-any.whl (21 kB)
# Using cached gspread_pandas-3.3.0-py2.py3-none-any.whl (27 kB)
# Using cached fsspec-2025.3.2-py3-none-any.whl (194 kB)
# Installing collected packages: python-gnupg, eep153_tools, ConsumerDemands, fsspec, CFEDemands, gspread_pandas
#   Attempting uninstall: gspread_pandas
#     Found existing installation: gspread-pandas 2.2.3
#     Uninstalling gspread-pandas-2.2.3:
#       Successfully uninstalled gspread-pandas-2.2.3
# Successfully installed CFEDemands-0.6.4.dev0 ConsumerDemands-0.4.3.dev0 eep153_tools-0.12.4 fsspec-2025.3.2 gspread_pandas-3.3.0 python-gnupg-0.5.4

# %% [markdown]
# The second prerequisite is a dataset including detailed information on
# household expenditures and characteristics.  The structure of that
# dataset is detailed in the next section.

# %% [markdown]
# ### Data

# %% [markdown]
# Consider the case in which the data are saved in a google sheet; we&rsquo;ll
# turn data from these into `pandas` dataframes.
# There are limits on the allowable size of google sheets (5 million
# cells when I last checked), so if your dataset is larger than this you&rsquo;ll need some other
# mechanism to get your data into such dataframes.  Even in this latter
# case you&rsquo;ll want your dataframes to have a structure that matches the
# description given below.

# %% [markdown]
# #### Structure of the Spreadsheet

# %% [markdown]
# An example spreadsheet with data for Uganda can be found at
# [https://docs.google.com/spreadsheets/d/1yFWlP5N7Aowaj6t2roRSFFUC50aFD-RLBGfzGtqLl0w/](https://docs.google.com/spreadsheets/d/1yFWlP5N7Aowaj6t2roRSFFUC50aFD-RLBGfzGtqLl0w/)
#
# This spreadsheet consists of several worksheets, labeled &ldquo;RDI&rdquo;, &ldquo;FCT&rdquo;,
# &ldquo;Household Characteristics&rdquo;, and a series of different years of food expenditures and prices
#
# Most worksheets have the initial three columns labeled &ldquo;i&rdquo;, &ldquo;t&rdquo;, and
# &ldquo;m&rdquo;; together these identify an observation uniquely.  The column &ldquo;i&rdquo;
# should include a household id; the column &ldquo;t&rdquo; should include an
# indicator for the year or period (for those of you with
# cross-sectional data these will all take a common value, e.g., 2019);
# the column &ldquo;m&rdquo; should be an indicator of &ldquo;market&rdquo;, which may be a
# region identifier, or may take a single value (e.g., &ldquo;Uganda&rdquo;).
#
# The triple (i,t,m) will serve as the index of some constructed
# dataframes.  It is important not to have **too** many different values
# for &ldquo;m&rdquo; (unless you have lots of data and RAM to play with).
#
# Beyond the first three columns, the &ldquo;Expenditures&rdquo; worksheet for a given year should have one index (or alternatively, one column) for each category of expenditures (e.g., &ldquo;Beans&rdquo;, &ldquo;Beef&rdquo;, &ldquo;Beer&rdquo;,&#x2026;).
#
# Beyond the first three columns, the &ldquo;Household Characteristics&rdquo; should
# have columns corresponding to different elements of the vector of
# observable characteristics $z$.  If the data permit, I recommend
# constructing observables that match what I have in these data:
# namely numbers of different children by age and sex, along with the
# logarithm of total household size (&ldquo;log HSize&rdquo;).

# %% [markdown]
# #### From Sheet to DataFrame to Regression Object

# %% [markdown]
# We begin by defining a dictionary that contains the spreadsheet key.
# One is provided for the Ugandan example that I wish to work
# through.

# %%
Ethiopia = '1qOZi1FqAS89x461pCIgwRaAfpBw5aUp7kBbp0tQKI_E'

# %% [markdown]
# With the spreadsheet defined , grab it and define a couple of
# dataframes. (Sheets should be shared with `students@eep153.iam.gserviceaccount.com`):

# %%
import pandas as pd
import numpy as np
from eep153_tools.sheets import read_sheets

# Change 'Uganda_Data' to key of your own sheet in Sheets, above
x = read_sheets(Ethiopia,sheet='Food Expenditures (2011-12)')
x['i'] = x['i'].astype(str)
x = x.set_index(['i','t','m','j']).squeeze()


# Now prices
p = read_sheets(Ethiopia,sheet='Food Prices (2011-12)').set_index(['t','m','j','u'])

# Compute medians of prices for particular time, place and unit
p = p.groupby(['t','m','j','u']).median()

# Just keep metric units
p = p.xs('Kg',level="u").squeeze().unstack('j')

# Drop prices for goods we don't have expenditures for
p = p[x.index.levels[-1]].T

# Household characteristics
d = read_sheets(Ethiopia,sheet="Household Characteristics")
d.columns.name = 'k'

# Fill blanks with zeros
d = d.replace(np.nan,0)

# Expenditures x may have duplicate columns
x = x.T.groupby(['i','t','m','j']).sum()
x = x.replace(0,np.nan) # Replace zeros with missing

# Take logs of expenditures; call this y
y = np.log(x)

d.set_index(['i','t','m'],inplace=True)

# %% [markdown]
# This gives a dataframe of household characteristics $d$ with a simple structure.

# %% [markdown]
# ### Estimation

# %% [markdown]
# Let $y_{i}^j$ be log expenditures on food $j$ by household $i$ at a particular time.  We want to estimate a regression that takes the form
# $$
#       y^j_{i} = A^j(p) + \gamma_j'd_i + \beta_j w_i + \zeta^j_i.
# $$
# We have data on `y` (log expenditures) and `d` (household characteristics).  This leaves the rest of the elements for us to estimate.

# %% [markdown]
# #### Basic Estimation

# %% [markdown]
# Just one line to set up the regression:

# %%
from cfe import Regression
import cfe
result = Regression(y=y,d=d)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[16], line 3
#       1 from cfe import Regression
#       2 import cfe
# ----> 3 result = Regression(y=y,d=d)
#
# File /srv/conda/lib/python3.11/site-packages/cfe/regression.py:810, in Regression.__init__(self, correct_miss, method, K, bootstrap_tol, compute_se, rectify, verbose, min_obs, min_prop_items, alltm, **kwargs)
#     807     self.attrs=attrs
#     809 if 'y' in kwargs.keys() and 'd' in kwargs.keys():
# --> 810     self.y,self.d = prepare_data(self.y,self.d,min_obs=min_obs,
#     811                                  min_prop_items=min_prop_items,
#     812                                  alltm=alltm)
#
# File /srv/conda/lib/python3.11/site-packages/cfe/regression.py:571, in prepare_data(y, d, min_obs, min_prop_items, alltm)
#     570 def prepare_data(y,d,min_obs=30,min_prop_items=0.1,alltm=False):
# --> 571     assert y.index.names == ['i','t','m','j']
#     573     # Drop household observations with fewer items than
#     574     # min_prop_items*number of items
#     575     Y = y.unstack('j')
#
# AssertionError:

# %% [markdown]
# And then one line to predict expenditures and estimate most of the things we need:

# %%
result.predicted_expenditures()
# Out:
# i                                 t        m         j
# 0007d1f1449242feb5a25429644fb991  2019-20  Northern  Avocado                    1836.603231
#                                                      Beans (dry)                8530.391173
#                                                      Beans (fresh)              4828.283261
#                                                      Beef                      15788.755164
#                                                      Bogoya                     4770.257706
#                                                                                    ...
# ffec87c6ae87498f956723afe69266b9  2019-20  Eastern   Sweet Potatoes (fresh)     8625.903421
#                                                      Tea (leaves)                218.108367
#                                                      Tomatoes                   1543.016198
#                                                      Waragi                     4677.821554
#                                                      Yams (arrowroot)           5174.268876
# Length: 93400, dtype: float64

# %% [markdown]
# Now we can compare predicted log expenditures with actual:

# %%
# %matplotlib inline
df = pd.DataFrame({'y':y,'yhat':result.get_predicted_log_expenditures()})
df.plot.scatter(x='yhat',y='y')
# Out:
# <Axes: xlabel='yhat', ylabel='y'>

# %% [markdown]
# That&rsquo;s all there is to estimation!  Note that we didn&rsquo;t estimate
# demands for all goods&#x2014;lots of goods didn&rsquo;t have enough observations,
# and were automatically dropped.

# %% [markdown]
# #### Parameters

# %% [markdown]
# ##### (Relative) Income Elasticity

# %% [markdown]
# Some of the parameters have an interesting interpretation.  First among these are the $\beta$ coefficients, which govern how *income elastic* different goods are (higher values means more elastic).  These are also called *Frisch elasticities*.
# Here we use a plot to visualize, with confidence intervals.

# %%
ax = result.graph_beta()

# %% [markdown]
# To just see the values of $\beta$:

# %%
result.get_beta()
# Out:
# j
# Ail                              0.946596
# Arachide                         0.748694
# Aubergine                        0.802377
# Beignets, galettes               0.458761
# Biscuit                          0.897087
# Café                             0.895229
# Caramel, bonbons, confiseries    0.705461
# Carotte                          0.910269
# Carpe                            0.906918
# Chou                             0.865919
# Concentré de tomate              1.523656
# Concombre                        0.467104
# Cube alimentaire                 1.380470
# Dattes                           0.856970
# Feuilles de Fakoye               0.327347
# Gombo                            0.938230
# Haricots secs                    0.541700
# Huile d'arachide                 1.943895
# Huile de palme                   1.444126
# Igname                           0.296902
# Lait caillé                      1.036559
# Lait en poudre                   0.616597
# Lait frais                       0.714353
# Mangue                           0.654592
# Mayonnaise                       1.414570
# Mil                              1.800836
# Oignon                           1.306229
# Orange                           0.928027
# Pain                             0.392100
# Pastèque                         0.557272
# Patate douce                     0.867224
# Piment                           0.838304
# Poisson fumé                     1.158868
# Poivre                           0.815037
# Poivron frais                    0.776338
# Pomme de terre                   0.703777
# Pâte d'arachide                  0.732845
# Pâtes alimentaires               0.354000
# Riz local Gambiaka               1.494270
# Riz local fumé                   0.736806
# Salade                           0.400942
# Sel                              1.034180
# Soumbala                         1.236473
# Sucre poudre                     1.043394
# Thé                              0.882894
# Tomate fraîche                   0.961677
# Viande de bœuf                   0.906935
# Viande de mouton                 1.000908
# Viande de poulet                 0.334126
# Vinaigre de citron               1.116259
# Œufs                             0.862129
# Name: beta, dtype: float64

# %% [markdown]
# ##### Demand and Household Composition

# %% [markdown]
# We&rsquo;re particularly interested in the effects of household composition on demand.  These are captured by the $\gamma_j$ parameters in the regression.

# %%
result.get_gamma()
# Out:
# k                               F 00-03   F 04-08   F 09-13   F 14-18  \
# j
# Ail                            0.003218  0.037723 -0.009107 -0.024645
# Arachide                      -0.082819 -0.029763 -0.037528 -0.032282
# Aubergine                     -0.109397  0.057948 -0.018883  0.033305
# Beignets, galettes            -0.091104 -0.003374 -0.012249 -0.006848
# Biscuit                       -0.067247  0.025256  0.001801  0.104319
# Café                          -0.108085 -0.087217 -0.106625 -0.006036
# Caramel, bonbons, confiseries -0.124343 -0.120497  0.098721 -0.124639
# Carotte                       -0.058579  0.074477 -0.074084 -0.000067
# Carpe                         -0.032884 -0.057923 -0.052613  0.034602
# Chou                          -0.049507  0.016027 -0.016808 -0.000469
# Concentré de tomate           -0.063335  0.014589  0.014153  0.035182
# Concombre                      0.005855 -0.044884 -0.093352  0.047385
# Cube alimentaire              -0.038796  0.073809  0.005237 -0.024037
# Dattes                        -0.294883 -0.130242 -0.052865 -0.027533
# Feuilles de Fakoye            -0.039213 -0.006820  0.012543  0.037096
# Gombo                          0.046026  0.038781 -0.014067 -0.003105
# Haricots secs                 -0.056267  0.032319  0.063531 -0.051530
# Huile d'arachide              -0.077172 -0.044896  0.027328  0.028011
# Huile de palme                -0.288526  0.060827  0.183379  0.076798
# Igname                        -0.114812 -0.037183  0.020417 -0.045091
# Lait caillé                   -0.188749  0.070744 -0.064754 -0.024326
# Lait en poudre                -0.112908 -0.000710 -0.020218  0.005140
# Lait frais                    -0.223705 -0.027579 -0.009644  0.047916
# Mangue                        -0.064054  0.022523  0.003297  0.134699
# Mayonnaise                    -0.000796  0.009273  0.041341  0.066194
# Mil                            0.053630  0.170917  0.252767  0.015371
# Oignon                        -0.102304 -0.029990 -0.060741  0.057972
# Orange                        -0.112754 -0.010110 -0.050886  0.054227
# Pain                          -0.076363 -0.061916 -0.016413  0.016329
# Pastèque                      -0.059852 -0.007328  0.032410 -0.045074
# Patate douce                  -0.057485  0.080310  0.063632  0.023709
# Piment                        -0.022376  0.066259 -0.003674 -0.007206
# Poisson fumé                  -0.000525  0.070878 -0.021104 -0.012107
# Poivre                         0.059108  0.039903  0.009504  0.030846
# Poivron frais                 -0.032579  0.058807 -0.005995 -0.002015
# Pomme de terre                -0.108136 -0.055854 -0.007923  0.090732
# Pâte d'arachide               -0.065827  0.001559  0.015720  0.028191
# Pâtes alimentaires            -0.090952  0.029680  0.006173 -0.010504
# Riz local Gambiaka            -0.168053 -0.074429 -0.031849 -0.071147
# Riz local fumé                 0.149262  0.100078  0.035631 -0.119497
# Salade                        -0.052136 -0.019756  0.051773 -0.016011
# Sel                           -0.084932  0.036225  0.007798 -0.030490
# Soumbala                      -0.072378  0.055444 -0.062483  0.007089
# Sucre poudre                  -0.082273 -0.007884  0.001741 -0.016305
# Thé                           -0.111822 -0.025233 -0.059308 -0.022371
# Tomate fraîche                -0.083712  0.053344 -0.005368  0.025911
# Viande de bœuf                -0.051298  0.030481  0.005472  0.001790
# Viande de mouton              -0.237119 -0.083142 -0.066271 -0.016473
# Viande de poulet              -0.072327  0.005302  0.045279  0.009363
# Vinaigre de citron             0.118944 -0.104370 -0.100856  0.003446
# Œufs                          -0.006208  0.014929 -0.072215 -0.013483
#
# k                               F 19-30   F 31-50     F 51+   M 00-03  \
# j
# Ail                            0.057742  0.082376  0.020902 -0.021479
# Arachide                      -0.010851  0.048824 -0.011499 -0.170036
# Aubergine                      0.052918  0.042652 -0.052226 -0.029101
# Beignets, galettes            -0.007735 -0.068803 -0.028786 -0.071075
# Biscuit                        0.036814 -0.025610 -0.087301 -0.173342
# Café                           0.038424 -0.051541 -0.173528 -0.155464
# Caramel, bonbons, confiseries  0.000521 -0.101307  0.039159 -0.195585
# Carotte                       -0.050249  0.109206  0.059047 -0.119138
# Carpe                          0.066346  0.088662 -0.022445 -0.048193
# Chou                           0.021691  0.069524  0.037731 -0.020971
# Concentré de tomate            0.109556  0.136864  0.045710 -0.029944
# Concombre                      0.053046  0.087460 -0.036655 -0.055993
# Cube alimentaire               0.030259  0.046029 -0.020733 -0.004566
# Dattes                         0.034324  0.002785 -0.376790 -0.404529
# Feuilles de Fakoye             0.063237  0.056472 -0.027840 -0.109262
# Gombo                          0.033772  0.026833  0.021549 -0.053360
# Haricots secs                  0.056685  0.047476  0.002892 -0.069160
# Huile d'arachide               0.081364  0.105213  0.030195 -0.019213
# Huile de palme                 0.041401 -0.058885 -0.117935 -0.183917
# Igname                         0.087460  0.116394  0.056641 -0.116770
# Lait caillé                    0.012669  0.047738 -0.126329 -0.254481
# Lait en poudre                 0.071622 -0.017967 -0.110758 -0.106332
# Lait frais                    -0.063182 -0.058895 -0.208059 -0.180160
# Mangue                         0.119777  0.048806  0.030124 -0.073093
# Mayonnaise                     0.039800  0.211129 -0.089711 -0.032378
# Mil                            0.065256  0.062166  0.283600  0.125123
# Oignon                         0.096008  0.058685 -0.050002 -0.095204
# Orange                         0.040371  0.044135 -0.012683 -0.156085
# Pain                          -0.003860 -0.039107 -0.066039 -0.093507
# Pastèque                       0.059138  0.032954 -0.077187 -0.076346
# Patate douce                   0.069855 -0.050010 -0.005746 -0.038752
# Piment                         0.043453  0.080217  0.071418 -0.031986
# Poisson fumé                   0.020333  0.061201  0.065962 -0.071839
# Poivre                         0.030954  0.049702  0.022716  0.057677
# Poivron frais                  0.032326  0.030486 -0.006908 -0.011840
# Pomme de terre                 0.076217 -0.003752  0.089374 -0.126177
# Pâte d'arachide                0.070156  0.077062  0.095949 -0.028912
# Pâtes alimentaires            -0.001495  0.033671 -0.004087 -0.076323
# Riz local Gambiaka             0.018455 -0.130492 -0.063648 -0.167691
# Riz local fumé                -0.076925 -0.008605  0.098398  0.002723
# Salade                         0.011831  0.100867  0.087371 -0.035030
# Sel                            0.057125  0.064748 -0.036915 -0.063340
# Soumbala                      -0.047239 -0.048368 -0.089341 -0.001288
# Sucre poudre                   0.038905  0.014586  0.011411 -0.097128
# Thé                           -0.002533  0.000480 -0.110113 -0.130304
# Tomate fraîche                 0.027230 -0.007298 -0.048519 -0.072640
# Viande de bœuf                 0.023438  0.060545  0.017109 -0.093153
# Viande de mouton               0.049015 -0.024702 -0.315640 -0.256416
# Viande de poulet               0.037156  0.062016 -0.046133 -0.037550
# Vinaigre de citron            -0.003511  0.091975 -0.170688  0.091206
# Œufs                           0.049567  0.135633  0.039324 -0.057987
#
# k                               M 04-08   M 09-13   M 14-18   M 19-30  \
# j
# Ail                            0.007027 -0.033503  0.031279  0.020157
# Arachide                       0.055055 -0.024577 -0.010914  0.018763
# Aubergine                     -0.013753 -0.051131 -0.054843  0.023151
# Beignets, galettes            -0.034870  0.033231  0.010502  0.040722
# Biscuit                        0.083980 -0.108236  0.005499  0.132353
# Café                          -0.011344  0.088333 -0.023990 -0.014396
# Caramel, bonbons, confiseries  0.132216  0.055309  0.012026 -0.247178
# Carotte                       -0.003377 -0.045760  0.024831  0.008402
# Carpe                         -0.061711 -0.067231  0.084162  0.053921
# Chou                           0.018284 -0.027922  0.012369 -0.008546
# Concentré de tomate            0.059810 -0.012374  0.019638  0.013832
# Concombre                     -0.008811 -0.058062  0.045039 -0.015916
# Cube alimentaire               0.056126 -0.037443  0.046262  0.034253
# Dattes                        -0.003064  0.083609 -0.099385  0.022626
# Feuilles de Fakoye             0.000224 -0.007538  0.012681  0.025525
# Gombo                         -0.018097  0.017228  0.045108  0.014387
# Haricots secs                  0.063764  0.001278  0.042630  0.054123
# Huile d'arachide              -0.065881 -0.058181  0.063835  0.026739
# Huile de palme                 0.183295  0.251744  0.053621  0.074450
# Igname                         0.084332  0.087987  0.002911  0.041131
# Lait caillé                   -0.009417 -0.019936 -0.068237  0.034470
# Lait en poudre                -0.002727 -0.010694  0.038883  0.025290
# Lait frais                    -0.003072  0.007793  0.059731  0.059094
# Mangue                        -0.011593  0.033741  0.053638  0.107305
# Mayonnaise                     0.001574 -0.060834  0.039581  0.046784
# Mil                            0.183798  0.184002  0.058802  0.030965
# Oignon                        -0.030639 -0.033263  0.030859  0.032728
# Orange                         0.009414 -0.127007  0.013054  0.095256
# Pain                          -0.033478 -0.035656  0.006763  0.018441
# Pastèque                      -0.020750 -0.097117 -0.000058  0.038147
# Patate douce                   0.122210 -0.025264 -0.005624 -0.058569
# Piment                         0.037772 -0.016164  0.031520  0.006310
# Poisson fumé                   0.032064 -0.055884  0.013406  0.014996
# Poivre                         0.059041 -0.025826  0.052120  0.030349
# Poivron frais                  0.035826 -0.000668 -0.010874  0.036693
# Pomme de terre                -0.034214  0.095908 -0.018168 -0.001757
# Pâte d'arachide                0.002279 -0.027686  0.033539  0.031718
# Pâtes alimentaires             0.010860  0.028490  0.042853  0.053090
# Riz local Gambiaka            -0.017681  0.003005 -0.173671  0.019387
# Riz local fumé                 0.082546  0.007316  0.124061  0.242369
# Salade                        -0.031428 -0.045529 -0.003416  0.049003
# Sel                            0.083376 -0.006093  0.037972  0.006630
# Soumbala                       0.043433 -0.009720  0.031466  0.012153
# Sucre poudre                   0.039243  0.001406 -0.008066  0.028126
# Thé                            0.057112 -0.013825 -0.010968  0.011384
# Tomate fraîche                 0.059205 -0.046168  0.004024  0.038481
# Viande de bœuf                 0.058610  0.027954  0.000664  0.058974
# Viande de mouton               0.068417  0.009809  0.023394  0.074952
# Viande de poulet               0.037781  0.114551 -0.011134  0.021897
# Vinaigre de citron            -0.085142  0.054735  0.099621  0.002207
# Œufs                          -0.029919 -0.117267  0.030070  0.005352
#
# k                               M 31-50     M 51+          M NA  log HSize  \
# j
# Ail                            0.018037  0.014737  1.679212e-15  -0.036908
# Arachide                       0.143430  0.086499 -2.775558e-17   0.221130
# Aubergine                      0.039502  0.057877  2.275957e-15   0.221699
# Beignets, galettes             0.077525  0.032065  0.000000e+00   0.405582
# Biscuit                        0.091502  0.055839 -3.330669e-16  -0.104129
# Café                           0.222744  0.080651  6.938894e-17   0.284784
# Caramel, bonbons, confiseries  0.143616 -0.069740  7.771561e-16   0.455266
# Carotte                       -0.045963 -0.004179  9.992007e-16   0.156248
# Carpe                          0.182300  0.060185  1.665335e-16   0.113479
# Chou                           0.001597  0.061878  7.494005e-16   0.226151
# Concentré de tomate            0.032967  0.094876 -2.775558e-17  -0.161306
# Concombre                     -0.037218  0.000200 -3.885781e-16   0.297494
# Cube alimentaire               0.035258  0.097572  6.938894e-18   0.090506
# Dattes                         0.368475 -0.004757  0.000000e+00   0.132883
# Feuilles de Fakoye             0.101322  0.049841  5.828671e-16   0.167182
# Gombo                          0.004057 -0.110306  2.775558e-17   0.256940
# Haricots secs                  0.094569  0.038036 -2.393918e-16   0.261692
# Huile d'arachide               0.036535 -0.018134  1.249001e-16   0.242552
# Huile de palme                 0.323199 -0.011717  1.110223e-16  -0.632918
# Igname                         0.012470 -0.134283  2.220446e-16   0.219888
# Lait caillé                    0.181815 -0.020758 -1.665335e-16   0.109258
# Lait en poudre                 0.094338 -0.028840 -2.081668e-16   0.018909
# Lait frais                     0.175827 -0.129333 -3.330669e-16   0.181192
# Mangue                         0.178006  0.156271  0.000000e+00   0.109256
# Mayonnaise                     0.150291  0.169324  6.106227e-16   0.000812
# Mil                            0.101168  0.277566  9.575674e-16  -0.354245
# Oignon                         0.109923 -0.079323  3.261280e-16   0.131738
# Orange                         0.170832  0.073496  2.220446e-16   0.259634
# Pain                           0.018429  0.016231 -4.718448e-16   0.724712
# Pastèque                       0.009887 -0.053988  1.110223e-16   0.397719
# Patate douce                   0.011915  0.047692  0.000000e+00  -0.030141
# Piment                        -0.003431 -0.007332  0.000000e+00   0.022773
# Poisson fumé                   0.020797 -0.003754 -5.551115e-17   0.158409
# Poivre                        -0.062749 -0.001549 -5.134781e-16  -0.094888
# Poivron frais                  0.019951  0.084784 -8.881784e-16   0.034404
# Pomme de terre                 0.086235 -0.008984  3.885781e-16   0.267230
# Pâte d'arachide                0.076810 -0.018389 -5.551115e-16   0.229797
# Pâtes alimentaires             0.060081  0.062658 -9.020562e-16   0.307314
# Riz local Gambiaka             0.149797  0.156143 -1.387779e-17   0.983563
# Riz local fumé                -0.098580  0.254833 -3.330669e-16   0.276989
# Salade                         0.004332 -0.024827 -8.881784e-16   0.344970
# Sel                            0.051588 -0.022358  7.632783e-17   0.037425
# Soumbala                       0.022816  0.142344  4.996004e-16   0.179336
# Sucre poudre                   0.088550  0.007026 -2.081668e-17   0.132085
# Thé                            0.164352  0.023985  6.591949e-17   0.179742
# Tomate fraîche                 0.116157  0.015616  1.665335e-16  -0.034795
# Viande de bœuf                 0.102640  0.077327  5.551115e-17   0.113796
# Viande de mouton               0.269694 -0.234169  1.276756e-15   0.007216
# Viande de poulet              -0.042700 -0.040526  1.110223e-16   0.153892
# Vinaigre de citron             0.048695  0.044790 -2.775558e-16   0.224409
# Œufs                           0.049508  0.033306 -3.885781e-16   0.303437
#
# k                              F NA  Constant
# j
# Ail                             0.0  4.355309
# Arachide                        0.0  5.409861
# Aubergine                       0.0  4.728345
# Beignets, galettes              0.0  5.301816
# Biscuit                         0.0  5.070208
# Café                            0.0  5.789045
# Caramel, bonbons, confiseries   0.0  4.700280
# Carotte                         0.0  5.119598
# Carpe                           0.0  6.697657
# Chou                            0.0  4.773209
# Concentré de tomate             0.0  4.733662
# Concombre                       0.0  5.724674
# Cube alimentaire                0.0  4.229453
# Dattes                          0.0  6.262854
# Feuilles de Fakoye              0.0  5.668562
# Gombo                           0.0  5.389923
# Haricots secs                   0.0  6.771369
# Huile d'arachide                0.0  6.031040
# Huile de palme                  0.0  6.181837
# Igname                          0.0  6.738708
# Lait caillé                     0.0  5.807216
# Lait en poudre                  0.0  7.025545
# Lait frais                      0.0  6.103838
# Mangue                          0.0  5.960674
# Mayonnaise                      0.0  6.413543
# Mil                             0.0  7.545709
# Oignon                          0.0  5.776018
# Orange                          0.0  6.031647
# Pain                            0.0  5.878251
# Pastèque                        0.0  6.673278
# Patate douce                    0.0  5.459874
# Piment                          0.0  4.288673
# Poisson fumé                    0.0  6.405389
# Poivre                          0.0  3.928469
# Poivron frais                   0.0  4.349736
# Pomme de terre                  0.0  6.798086
# Pâte d'arachide                 0.0  5.819753
# Pâtes alimentaires              0.0  6.595123
# Riz local Gambiaka              0.0  8.450604
# Riz local fumé                  0.0  7.650827
# Salade                          0.0  5.990350
# Sel                             0.0  4.431846
# Soumbala                        0.0  4.458442
# Sucre poudre                    0.0  6.240298
# Thé                             0.0  5.426431
# Tomate fraîche                  0.0  5.040991
# Viande de bœuf                  0.0  6.920154
# Viande de mouton                0.0  7.090447
# Viande de poulet                0.0  7.740995
# Vinaigre de citron              0.0  4.194780
# Œufs                            0.0  6.469668

# %% [markdown]
# ##### Welfare

# %% [markdown]
# Another import quantity we estimate is $w_i$.  This is a welfare measure for the household.  Here&rsquo;s a histogram:

# %%
ax = result.get_w().plot.hist(bins=100,density=True)
result.get_w().plot.kde(ax=ax)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# #### Saving Result

# %% [markdown]
# You can save the estimated result, using something like

# %%
result.to_pickle('uganda_estimates.rgsn')

# %% [markdown]
# You can subsequently load this using

# %%
import cfe
result = cfe.regression.read_pickle('uganda_estimates.rgsn')

# %% [markdown]
# #### Demand and Utility

# %% [markdown]
# Having estimated the demand system, we can examine the implied demand curves.

# %% [markdown]
# ##### Budgets

# %% [markdown]
# Get food budget for all households, then find median budget:

# %%
import numpy as np

xhat = result.predicted_expenditures()

# Total food expenditures per household
xbar = xhat.groupby(['i','t','m']).sum()

# Reference budget
xref = xbar.quantile(0.5)  # Household at 0.5 quantile is median

# %% [markdown]
# ##### Reference Prices

# %% [markdown]
# Choose reference prices.  Here we&rsquo;ll choose a particular year, and average prices across markets.  If you wanted to focus on particular market you&rsquo;d do this differently.

# %%
# Reference prices chosen from a particular time; average across place.
# These are prices per kilogram:
pbar = p.mean(axis=1)
pbar = pbar[result.beta.index] # Only use prices for goods we can estimate

# Replace missing prices with 1 (this is because they're best measured in expenditures)
pbar = pbar.replace(np.nan,1)

#Finally, define a function to change a single price in the vector $p$:
def my_prices(p0,j,p=pbar):
    """
    Change price of jth good to p0, holding other prices fixed.
    """
    p = p.copy()
    p.loc[j] = p0
    return p

# %% [markdown]
# ##### Demand as a function of prices

# %% [markdown]
# Let&rsquo;s take a look at demand schedules for households with different budgets.

# %%
p
# Out:
# t                       2021-22                                         \
# m                        Bamako          Gao        Kayes        Kidal
# j
# Ail                  228.774413   298.965433   289.005366   639.183674
# Ananas              2985.054348  6458.333333  3125.000000          NaN
# Arachide             386.204562   621.651786    68.303618   441.071429
# Attiéke             1271.826923  1125.000000  2002.272727          NaN
# Aubergine            290.770762   506.916209   178.113073   856.250000
# ...                         ...          ...          ...          ...
# Viande de poulet    1688.162879  2413.825758  1487.121212  1025.000000
# Viande séchée        750.000000          NaN          NaN          NaN
# Vinaigre             208.554688   235.416667   126.562500          NaN
# Vinaigre de citron   330.497685   278.515625   116.133721    56.250000
# Œufs                 623.113256   258.428300   360.832518   533.482143
#
# t                                                                       \
# m                     Koulikoro        Mopti        Segou      Sikasso
# j
# Ail                  240.727807   300.003950   354.183733   352.097448
# Ananas              2544.642857  3802.083333  2718.750000          NaN
# Arachide              85.632954   149.838688   114.250528    54.542922
# Attiéke              776.699561   812.500000  1280.000000  1004.397321
# Aubergine            110.038194   138.729245   130.668831   188.986713
# ...                         ...          ...          ...          ...
# Viande de poulet    1646.153846  2307.142857  1362.237762  1142.857143
# Viande séchée               NaN   500.000000          NaN          NaN
# Vinaigre             350.000000   130.555556    89.062500   126.838235
# Vinaigre de citron   189.303183   116.540179    89.402174   243.750000
# Œufs                 406.183461   265.706624   259.290899   245.560573
#
# t
# m                     Tombouctou
# j
# Ail                   393.686430
# Ananas               3750.000000
# Arachide              532.966714
# Attiéke               629.166667
# Aubergine             382.145597
# ...                          ...
# Viande de poulet     1740.584416
# Viande séchée       12604.761900
# Vinaigre              145.348837
# Vinaigre de citron    205.368590
# Œufs                  328.048801
#
# [132 rows x 9 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

use = 'Ail'  # Good we want demand curve for

# Vary prices from 50% to 200% of reference.
scale = np.linspace(.5,2,20)

# Demand for Millet for household at median budget
plt.plot([result.demands(xref,my_prices(pbar[use]*s,use,pbar))[use] for s in scale],scale)

# Demand for Millet for household at 25% percentile
plt.plot([result.demands(xbar.quantile(0.25),my_prices(pbar[use]*s,use,pbar))[use] for s in scale],scale)

# Demand for Millet for household at 75% percentile
plt.plot([result.demands(xbar.quantile(0.75),my_prices(pbar[use]*s,use,pbar))[use] for s in scale],scale)

plt.ylabel(f"Price (relative to base of {pbar[use]:.2f})")
plt.xlabel(f"Quantities of {use} Demanded")
# Out:
# Text(0.5, 0, 'Quantities of Ail Demanded')

# %% [markdown]
# ##### Engel Curves

# %% [markdown]
# Engel curves trace out how demand changes with budget:

# %%
fig,ax = plt.subplots()

ax.plot(np.log(scale*xref),[result.expenditures(s*xref,pbar)/(s*xref) for s in scale])
ax.set_xlabel(f'log budget (relative to base of {xref:.0f}')
ax.set_ylabel(f'Expenditure share')
ax.set_title('Engel Curves')
# Out:
# Text(0.5, 1.0, 'Engel Curves')

# %% [markdown]
# ##### Indirect Utility

# %% [markdown]
# We can also describe an indirect utility function that corresponds to these demands:

# %%
fig,ax = plt.subplots()

ax.plot(scale*xref,[result.indirect_utility(s*xref,pbar) for s in scale])
ax.set_xlabel(f'Indirect Utility (Budget relative to base of {xref:.0f}')
ax.set_ylabel(f'Utility')
ax.set_title('Indirect Utility Function')
# Out:
# Text(0.5, 1.0, 'Indirect Utility Function')
