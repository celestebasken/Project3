# %% [markdown]
# ## Preface

# %% [markdown]
# If need be&#x2026;

# %%
# !pip install -r requirements.txt
# Out:
# Collecting CFEDemands>=0.6.3.dev0 (from -r requirements.txt (line 5))
#   Using cached cfedemands-0.6.4.dev0-py2.py3-none-any.whl.metadata (1.6 kB)
# Collecting ConsumerDemands>=0.4.3.dev0 (from -r requirements.txt (line 7))
#   Using cached ConsumerDemands-0.4.3.dev0-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: matplotlib>=3.3.4 in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 10)) (3.10.1)
# Requirement already satisfied: numpy>=1.21.5 in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 14)) (2.2.4)
# Requirement already satisfied: pandas>=1.3.5 in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 20)) (2.2.3)
# Requirement already satisfied: plotly>=5.1.0 in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 23)) (6.0.1)
# Collecting eep153_tools>=0.11 (from -r requirements.txt (line 25))
#   Using cached eep153_tools-0.12.4-py2.py3-none-any.whl.metadata (363 bytes)
# Collecting python-gnupg (from -r requirements.txt (line 26))
#   Using cached python_gnupg-0.5.4-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting gspread_pandas>=3.3 (from -r requirements.txt (line 28))
#   Using cached gspread_pandas-3.3.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: scikit-learn in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 30)) (1.6.0)
# Requirement already satisfied: xarray in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 31)) (2025.1.1)
# Requirement already satisfied: scipy>=1.7.3 in /srv/conda/lib/python3.11/site-packages (from CFEDemands>=0.6.3.dev0->-r requirements.txt (line 5)) (1.14.1)
# Requirement already satisfied: importlib_metadata>=6.7.0 in /srv/conda/lib/python3.11/site-packages (from CFEDemands>=0.6.3.dev0->-r requirements.txt (line 5)) (8.6.1)
# Collecting fsspec (from CFEDemands>=0.6.3.dev0->-r requirements.txt (line 5))
#   Using cached fsspec-2025.3.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (24.2)
# Requirement already satisfied: pillow>=8 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/lib/python3.11/site-packages (from pandas>=1.3.5->-r requirements.txt (line 20)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/lib/python3.11/site-packages (from pandas>=1.3.5->-r requirements.txt (line 20)) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in /srv/conda/lib/python3.11/site-packages (from plotly>=5.1.0->-r requirements.txt (line 23)) (1.33.0)
# Requirement already satisfied: gspread<6,>=5.0.0 in /srv/conda/lib/python3.11/site-packages (from gspread_pandas>=3.3->-r requirements.txt (line 28)) (5.12.4)
# Requirement already satisfied: decorator in /srv/conda/lib/python3.11/site-packages (from gspread_pandas>=3.3->-r requirements.txt (line 28)) (5.1.1)
# Requirement already satisfied: google-auth in /srv/conda/lib/python3.11/site-packages (from gspread_pandas>=3.3->-r requirements.txt (line 28)) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib in /srv/conda/lib/python3.11/site-packages (from gspread_pandas>=3.3->-r requirements.txt (line 28)) (1.2.1)
# Requirement already satisfied: joblib>=1.2.0 in /srv/conda/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 30)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /srv/conda/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 30)) (3.6.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /srv/conda/lib/python3.11/site-packages (from google-auth->gspread_pandas>=3.3->-r requirements.txt (line 28)) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /srv/conda/lib/python3.11/site-packages (from google-auth->gspread_pandas>=3.3->-r requirements.txt (line 28)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /srv/conda/lib/python3.11/site-packages (from google-auth->gspread_pandas>=3.3->-r requirements.txt (line 28)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /srv/conda/lib/python3.11/site-packages (from google-auth-oauthlib->gspread_pandas>=3.3->-r requirements.txt (line 28)) (2.0.0)
# Requirement already satisfied: zipp>=3.20 in /srv/conda/lib/python3.11/site-packages (from importlib_metadata>=6.7.0->CFEDemands>=0.6.3.dev0->-r requirements.txt (line 5)) (3.21.0)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->-r requirements.txt (line 10)) (1.17.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /srv/conda/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth->gspread_pandas>=3.3->-r requirements.txt (line 28)) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /srv/conda/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gspread_pandas>=3.3->-r requirements.txt (line 28)) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /srv/conda/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gspread_pandas>=3.3->-r requirements.txt (line 28)) (2.32.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/lib/python3.11/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib->gspread_pandas>=3.3->-r requirements.txt (line 28)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.11/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib->gspread_pandas>=3.3->-r requirements.txt (line 28)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.11/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib->gspread_pandas>=3.3->-r requirements.txt (line 28)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.11/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib->gspread_pandas>=3.3->-r requirements.txt (line 28)) (2025.1.31)
# Using cached cfedemands-0.6.4.dev0-py2.py3-none-any.whl (45 kB)
# Using cached ConsumerDemands-0.4.3.dev0-py2.py3-none-any.whl (12 kB)
# Using cached eep153_tools-0.12.4-py2.py3-none-any.whl (4.9 kB)
# Using cached python_gnupg-0.5.4-py2.py3-none-any.whl (21 kB)
# Using cached gspread_pandas-3.3.0-py2.py3-none-any.whl (27 kB)
# Using cached fsspec-2025.3.2-py3-none-any.whl (194 kB)
# Installing collected packages: python-gnupg, eep153_tools, ConsumerDemands, fsspec, CFEDemands, gspread_pandas
#   Attempting uninstall: gspread_pandas
#     Found existing installation: gspread-pandas 2.2.3
#     Uninstalling gspread-pandas-2.2.3:
#       Successfully uninstalled gspread-pandas-2.2.3
# Successfully installed CFEDemands-0.6.4.dev0 ConsumerDemands-0.4.3.dev0 eep153_tools-0.12.4 fsspec-2025.3.2 gspread_pandas-3.3.0 python-gnupg-0.5.4

# %% [markdown]
# ## Introduction

# %% [markdown]
# Here we give a set of generic instructions for analyzing demand for
# food and nutrition.  Inputs include a datasets of consumption
# quantities, consumption expenditures, household characteristics, and a
# food conversion table.
#
# The different datasets should be indexed as follows:
#
#
# | Dataset|Indexed by|Columns|
# |---|---|---|
# | Expenditures|i,t,m|j|
# | Consumption|i,t,m,u|j|
# | Prices|j,u|t,m|
# | HH Characteristics|i,t,m|k|
# | FCT|j,u|n|
# | RDI|n|k|
#
# where `i` indexes households, `t` indexes periods, `m` indexes
# markets, `j` indexes goods, `k` indexes different kinds of household
# characteristics, `u` indexes different unit names, and `n` indexes
# different nutrients.  Finally, any RDI (&ldquo;recommended daily intake&rdquo;)
# tables should be indexed by nutrients, with columns corresponding to
# characteristics of persons within the household (e.g., age & sex
# categories).
#
# Note that some countries have more than one dataframe of consumption,
# distinguished by source; for example Malawi has consumption items
# purchased as well as consumption items produced.  Here we focus on
# consumption purchases, since one of our immediate aims is to infer
# prices paid.

# %% [markdown]
# ## Step 1: Acquire DataFrames

# %% [markdown]
# Here are addresses of google sheets for different dataframes for the
# case of Uganda:

# %%
InputFiles = {'Expenditures':('1qOZi1FqAS89x461pCIgwRaAfpBw5aUp7kBbp0tQKI_E','Food Expenditures (2011-12)'),
              'Prices':('1qOZi1FqAS89x461pCIgwRaAfpBw5aUp7kBbp0tQKI_E','Food Prices (2011-12)'),
              'HH Characteristics':('1qOZi1FqAS89x461pCIgwRaAfpBw5aUp7kBbp0tQKI_E','Household Characteristics'),
              'FCT':('1qOZi1FqAS89x461pCIgwRaAfpBw5aUp7kBbp0tQKI_E','FCT'),
              'RDI':('1yVLriVpo7KGUXvR3hq_n53XpXlD5NmLaH1oOMZyV0gQ','RDI'),}

# %% [markdown]
# Note that in some cases not the food items for the FCT (e.g., for Niger) are **not** yet all matched up (&ldquo;harmonized&rdquo;) with food labels indexed by `j` in the expenditure,
# consumption and price datasets.

# %%
from eep153_tools.sheets import read_sheets
import numpy as np
import pandas as pd

def get_clean_sheet(key,sheet=None):

    df = read_sheets(key,sheet=sheet)
    df.columns = [c.strip() for c in df.columns.tolist()]

    df = df.loc[:,~df.columns.duplicated(keep='first')]   

    df = df.drop([col for col in df.columns if col.startswith('Unnamed')], axis=1)

    df = df.loc[~df.index.duplicated(), :]

    return df

# Get expenditures...
x = get_clean_sheet(InputFiles['Expenditures'][0],
                    sheet=InputFiles['Expenditures'][1])

if 'm' not in x.columns:
    x['m'] = 1

## important to keep the type of household id value as str.
x['i'] = x['i'].astype(str)

x = x.set_index(['i','t','m', 'j'])


# x = x.apply(lambda x: pd.to_numeric(x,errors='coerce'))
x = x.replace(0,np.nan)

# Get HH characteristics...
z = get_clean_sheet(InputFiles['HH Characteristics'][0],
                    sheet=InputFiles['HH Characteristics'][1])

if 'm' not in z.columns:
    z['m'] = 1

z = z.set_index(['i','t','m'])
z.columns.name = 'k'

z = z.apply(lambda x: pd.to_numeric(x,errors='coerce'))

# Get prices
p = get_clean_sheet(InputFiles['Prices'][0],
                    sheet=InputFiles['Prices'][1])

if 'm' not in p.columns:  # Supply "market" indicator if missing
    p['m'] = 1

p = p[p['u'] == 'Kg']
p = p.drop(columns = ['u'])
p = p.set_index(['t','m', 'j'])

p = p.replace(0,np.nan)

fct = get_clean_sheet(InputFiles['FCT'][0],
                    sheet=InputFiles['FCT'][1])

#### This bit peculiar to Niger FCT #####
#fct = fct.loc[fct.Code.str.len()==6]
#fct = fct.set_index('Code')
#fct.columns = [v.replace('\n',' ') for v in fct.columns]
########################################
fct = fct.rename(columns={'index':'j'})
fct = fct.set_index('j')
fct.columns.name = 'n'

fct = fct.apply(lambda x: pd.to_numeric(x,errors='coerce'))

################## RDI, if available (consider using US) #####################
rdi = get_clean_sheet(InputFiles['RDI'][0],
                    sheet=InputFiles['RDI'][1])
rdi = rdi.set_index('n')
rdi.columns.name = 'k'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_75/1807713033.py in ?()
#      67 fct = fct.T
#      68 fct.columns = fct.iloc[0]
#      69 fct = fct[1:]
#      70 fct = fct.rename(columns={'nutrition':'j'})
# ---> 71 fct = fct.set_index('j')
#      72 fct.columns.name = 'n'
#      73
#      74 fct = fct.apply(lambda x: pd.to_numeric(x,errors='coerce'))
#
# /srv/conda/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['j'] are in the columns"

# %%
# %debug
# Out:
# > /srv/conda/lib/python3.11/site-packages/pandas/core/frame.py(6122)set_index()
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
# ipdb>  up
# > /tmp/ipykernel_75/1807713033.py(71)<module>()
#      69 fct = fct[1:]
#      70 fct = fct.rename(columns={'nutrition':'j'})
# ---> 71 fct = fct.set_index('j')
#      72 fct.columns.name = 'n'
#      73
# ipdb>  fct
# nutrition                      Energy  Protein Vitamin A Vitamin D Vitamin E  \
# Avocado                   1601.338432     20.0      70.0       0.0      20.7
# Banana                            890       11        30         0         1
# Barley                           3490      123         0         0        10
# Beef                             3230      249         0         0         0
# Beer                              410        3         0         0         0
# Beetroot                   430.210325     16.1      20.0       0.0       0.4
# Berbere                     74.869981  8.95625       0.0       0.0       0.0
# Boye/Yam                          970       21         0         0        50
# Bread/biscuit                    2740       80         0         0         0
# Butter/ghee                      8760        3      9250        20        30
# Cassava                          1600       14        10         0         2
# Cheese                           3490       76      3660         0         3
# Coffee                           2000      100         0         0         0
# Eggs                             2780      192      8100        80        20
# Fenugreek                 3231.357553    230.0      30.0       0.0       0.0
# Fish                             1120      214       430       120        10
# Garlic                    1489.005736     63.6       0.0       0.0       0.8
# Goat & mutton meat               2690      249         0         0         0
# Ground nuts                      5670      258         0         0        90
# Honey                            3040        3         0         0         0
# Injera                      207.93499     34.8       0.0       0.0       0.8
# Leafy Greens                      230       30      8190         0        10
# Linseed                          5880      264        70         0        20
# Maize                             590       18        70         0         0
# Mango                             650        5       380         0        11
# Meat                             1670      245       270         0         0
# Milk                              600       32       280         0         1
# Moringa/Shiferaw/Halloka   640.535373     94.0    3780.0       0.0       0.0
# Oats                      3891.013384    168.9       0.0       0.0       0.0
# Oils                             8620        0         0         0        10
# Onion                             400       13         0         0         0
# Orange                            470        9        80         0         0
# Other cereal                        0        0         0         0         0
# Other pulse or nut               1160       90        30         0         0
# Other vegetable                   230       85      1460         0         0
# Papaya                     427.820268      4.7     470.0       0.0       3.0
# Pasta/Macaroni                   3710      105         0         0         0
# Potato                            930       20         0         0        67
# Rice                             3580       65         0         0         0
# Salt                                0        0         0         0         0
# Soda                              540        2      1680         0         0
# Sorghum                          3280       66        50         0         0
# Sugar                            3870        0         0         0         0
# Sweet potato                      740       12     10560         0        40
# Tea                                10        0         0         0         0
# Teff                      3671.128107    133.0       0.0       0.0       0.8
# Tella                             410        3         0         0         0
#
# nutrition                Vitamin C Vitamin B-6 Vitamin B-12 Calcium Magnesium  \
# Avocado                      100.0        2.57          0.0   120.0     290.0
# Banana                          87           4            0      50       270
# Barley                           0           2            0     260       920
# Beef                             0           3           19      40       230
# Beer                             0           1            0      50        60
# Beetroot                      49.0        0.67          0.0   160.0     230.0
# Berbere                     1417.0       3.027          0.0   63.61     109.8
# Boye/Yam                       120           2            0      80       260
# Bread/biscuit                    0           0            0     100       270
# Butter/ghee                      0           0            0      80        10
# Cassava                        206           1            0     160       210
# Cheese                           0           0            4     800        60
# Coffee                           0           0            0    3000      4000
# Eggs                             0           4           81     960       260
# Fenugreek                     30.0         6.0          0.0  1760.0    1910.0
# Fish                             0           3           11     480       860
# Garlic                       312.0       12.35          0.0  1810.0     250.0
# Goat & mutton meat               0           3           19      40       230
# Ground nuts                      0           3            0     920      1680
# Honey                           10           0            0      60        20
# Injera                         0.0        1.43          0.0   130.0     640.0
# Leafy Greens                   100           2            0    1360       870
# Linseed                          0           2            0    1310      3470
# Maize                           30           0            0      10       180
# Mango                          277           1            0     100        90
# Meat                             0           2            2      90       140
# Milk                             0           0            4    1150       120
# Moringa/Shiferaw/Halloka     517.0        12.0          0.0  1850.0     420.0
# Oats                           0.0        1.19          0.0   540.0    1770.0
# Oils                             0           0            0       0         0
# Onion                           74           1            0     230       100
# Orange                         530           1            0     400       100
# Other cereal                     0           0            0       0         0
# Other pulse or nut              50           5            0     510       960
# Other vegetable                445           2            0     969       550
# Papaya                       609.0        0.38          0.0   200.0     210.0
# Pasta/Macaroni                   0           0            0     150       220
# Potato                         186           7            0      50       250
# Rice                             0           1            0      80       360
# Salt                             0           0            0     450        20
# Soda                           150           1            0      40        40
# Sorghum                          0           2            0    2750       270
# Sugar                            0           0            0      10         0
# Sweet potato                   180           2            0     200       140
# Tea                              0           0            0      20        20
# Teff                           0.0        4.82          0.0  1800.0    1840.0
# Tella                            0           1            0      50        60
#
# nutrition                 ...   Zinc  Fiber  Folate Carbohydrate Niacin  \
# Avocado                   ...    6.4   67.0   810.0         85.3  17.38
# Banana                    ...      2      0       0            0      0
# Barley                    ...     20      0       0            0      0
# Beef                      ...     41      0       0            0      0
# Beer                      ...      0      0       0            0      0
# Beetroot                  ...    3.5   28.0  1090.0         95.6   3.34
# Berbere                   ...  2.023  11.58   473.2     66.53175  10.24
# Boye/Yam                  ...      5      0       0            0      0
# Bread/biscuit             ...      9      0       0            0      0
# Butter/ghee               ...      0      0       0            0      0
# Cassava                   ...      3      0       0            0      0
# Cheese                    ...      5      0       0            0      0
# Coffee                    ...      0      0       0            0      0
# Eggs                      ...     21      0       0            0      0
# Fenugreek                 ...   25.0  246.0   570.0        583.5   16.4
# Fish                      ...      4      0       0            0      0
# Garlic                    ...   11.6   21.0    30.0        330.6    7.0
# Goat & mutton meat        ...     41      0       0            0      0
# Ground nuts               ...     33      0       0            0      0
# Honey                     ...      2      0       0            0      0
# Injera                    ...    8.5   27.0   290.0        182.9  17.12
# Leafy Greens              ...      8      0       0            0      0
# Linseed                   ...    103      0       0            0      0
# Maize                     ...      3      0       0            0      0
# Mango                     ...      0      0       0            0      0
# Meat                      ...     13      0       0            0      0
# Milk                      ...      0      0       0            0      0
# Moringa/Shiferaw/Halloka  ...    6.0   20.0   400.0         82.8   22.2
# Oats                      ...   39.7  106.0   560.0        662.7   9.61
# Oils                      ...      0      0       0            0      0
# Onion                     ...      2      0       0            0      0
# Orange                    ...      1      0       0            0      0
# Other cereal              ...      0      0       0            0      0
# Other pulse or nut        ...     35      0       0            0      0
# Other vegetable           ...      6      0       0            0      0
# Papaya                    ...    0.8   17.0   370.0        108.2   3.57
# Pasta/Macaroni            ...      1      0       0            0      0
# Potato                    ...      3      0       0            0      0
# Rice                      ...     11      0       0            0      0
# Salt                      ...      0      0       0            0      0
# Soda                      ...      0      0       0            0      0
# Sorghum                   ...     12      0       0            0      0
# Sugar                     ...      0      0       0            0      0
# Sweet potato              ...      2      0       0            0      0
# Tea                       ...      0      0       0            0      0
# Teff                      ...   36.3   80.0     0.0        731.3  33.63
# Tella                     ...      0      0       0            0      0
#
# nutrition                Phosphorus Potassium Riboflavin Thiamin Vitamin K
# Avocado                       520.0    4850.0        1.3    0.67     210.0
# Banana                            0         0          0       0         0
# Barley                            0         0          0       0         0
# Beef                              0         0          0       0         0
# Beer                              0         0          0       0         0
# Beetroot                      400.0    3250.0        0.4    0.31       2.0
# Berbere                       265.9    2127.0      1.422  0.5494       0.0
# Boye/Yam                          0         0          0       0         0
# Bread/biscuit                     0         0          0       0         0
# Butter/ghee                       0         0          0       0         0
# Cassava                           0         0          0       0         0
# Cheese                            0         0          0       0         0
# Coffee                            0         0          0       0         0
# Eggs                              0         0          0       0         0
# Fenugreek                    2960.0    7700.0       3.66    3.22       0.0
# Fish                              0         0          0       0         0
# Garlic                       1530.0    4010.0        1.1     2.0      17.0
# Goat & mutton meat                0         0          0       0         0
# Ground nuts                       0         0          0       0         0
# Honey                             0         0          0       0         0
# Injera                        890.0    1520.0       0.76    1.74      17.0
# Leafy Greens                      0         0          0       0         0
# Linseed                           0         0          0       0         0
# Maize                             0         0          0       0         0
# Mango                             0         0          0       0         0
# Meat                              0         0          0       0         0
# Milk                              0         0          0       0         0
# Moringa/Shiferaw/Halloka     1120.0    3370.0        6.6    2.57       0.0
# Oats                         5230.0    4290.0       1.39    7.63       0.0
# Oils                              0         0          0       0         0
# Onion                             0         0          0       0         0
# Orange                            0         0          0       0         0
# Other cereal                      0         0          0       0         0
# Other pulse or nut                0         0          0       0         0
# Other vegetable                   0         0          0       0         0
# Papaya                        100.0    1820.0       0.27    0.23      26.0
# Pasta/Macaroni                    0         0          0       0         0
# Potato                            0         0          0       0         0
# Rice                              0         0          0       0         0
# Salt                              0         0          0       0         0
# Soda                              0         0          0       0         0
# Sorghum                           0         0          0       0         0
# Sugar                             0         0          0       0         0
# Sweet potato                      0         0          0       0         0
# Tea                               0         0          0       0         0
# Teff                         4290.0    4270.0        2.7     3.9      19.0
# Tella                             0         0          0       0         0
#
# [47 rows x 21 columns]
# ipdb>  fct.columns
# Index(['Energy', 'Protein', 'Vitamin A', 'Vitamin D', 'Vitamin E', 'Vitamin C',
#        'Vitamin B-6', 'Vitamin B-12', 'Calcium', 'Magnesium', 'Iron', 'Zinc',
#        'Fiber', 'Folate', 'Carbohydrate', 'Niacin', 'Phosphorus', 'Potassium',
#        'Riboflavin', 'Thiamin', 'Vitamin K'],
#       dtype='object', name='nutrition')

# %% [markdown]
# ## Step 2: Estimate Demand System

# %% [markdown]
# Here, use data on log *expenditures* and household characteristics to
# create a CFEDemand `Regression` result.

# %%
import cfe

result = cfe.Regression(y=np.log(x['Expenditure']),d=z)

result.get_beta().sort_values(ascending=False) # Check sanity...
# Out:
# j
# Maize        0.677973
# Wheat        0.631319
# Teff         0.567075
# Coffee       0.539258
# Banana       0.527397
# Onion        0.510546
# Sugar        0.492017
# Chat/Kat     0.459318
# Meat         0.440854
# Field Pea    0.425250
# Sorghum      0.377076
# Potato       0.336244
# Milk         0.286823
# Eggs         0.275389
# Salt         0.228052
# Name: beta, dtype: float64

# %% [markdown]
# Make this persistent&#x2026;

# %%
result.to_pickle('./foo.pickle')

# %% [markdown]
# ## Step 3: Infer quantities

# %% [markdown]
# Next, we divide predicted expenditures by prices to get
# quantities (in kilograms) we can map into the  FCT.

# %%
import cfe

result = cfe.read_pickle('foo.pickle')  # Get persistent result saved above...

xhat = result.predicted_expenditures()

# Expenditures divided by prices/kg gives quantities in kgs...
qhat = (xhat.unstack('j')/p['Price'].unstack('j')).dropna(how='all')

# Drop missing columns
qhat = qhat.loc[:,qhat.count()>0]

# %% [markdown]
# Note that `qhat` may give prices for different *units*.  If prices
# differ **only** because of units (e.g., one deciliter costs one
# tenth as much as a liter), then we can use these differences in prices
# to convert between different units, even if the units (e.g., &ldquo;basket&rdquo;)
# is otherwise unclear.
#
# If we have enough data on purchases in kilograms, just keep those
# prices (otherwise choose some other useful unit).  We also assume
# prices are the same for everyone, so just take median.

# %% [markdown]
# ## Step 4: Map predicted quantities into nutrients

# %% [markdown]
# Before this will work, need columns of qhat to match columns of fct.

# %%
use = fct.index.intersection(qhat.columns)


nutrients = qhat[use]@fct.loc[use,:]
nutrients.mean()    # NB: Nutrients are for past /week/ for entire household. (Depends on dataset)
# Out:
# n
# Energy          108337.974482
# Protein           1773.826524
# Vitamin A        10816.594128
# Vitamin D           90.194739
# Vitamin E           94.870811
# Vitamin C          510.109951
# Vitamin B-6         51.959447
# Vitamin B-12       101.994660
# Calcium          28347.784970
# Magnesium        14160.044863
# Iron               655.914074
# Zinc               307.973854
# Fiber              391.916338
# Folate               0.000000
# Carbohydrate      3582.605228
# Niacin             164.751831
# Phosphorus       21016.513643
# Potassium        20918.534558
# Riboflavin          13.227176
# Thiamin             19.105921
# Vitamin K           93.080130
# dtype: float64

# %% [markdown]
# ## Household Nutritional Adequacy

# %% [markdown]
# Our data on demand and nutrients is at the *household* level; we
#    can&rsquo;t directly compare household level nutrition with individual
#    level requirements.  What we **can** do is add up minimum individual
#    requirements, and see whether household total exceed these.  This
#    isn&rsquo;t a guarantee that all individuals have adequate nutrition
#    (since the way food is allocated in the household might be quite
#    unequal, or unrelated to individual requirements), but it is
#    *necessary* if all individuals are to have adequate nutrition.
#
# For each household, we know the numbers of people in different age-sex categories.  We can match these up with data from an RDI (Recommended Dietary Intakes), then sum over different types.

# %%
z.columns = [
    col.replace('Females', 'F')
       .replace('Males', 'M')
       .replace('51-99', '51+')
    for col in z.columns
]

# %%
z = z[rdi.columns.tolist()]

hh_rdi = z@rdi.T

# Uganda data is per week, so make this a recommended WEEKLY intake:
hh_rwi = hh_rdi*7

# %% [markdown]
# Now, what proportion of `hh_rwi` do households consume?

# %%
# Match up nutrient names
use_nutrients = nutrients.columns.intersection(hh_rwi.columns)

nutrient_ratio = (nutrients[use_nutrients]/hh_rwi[use_nutrients]).dropna()

nutrient_ratio
# Out:
# n                               Energy   Protein  Vitamin A  Vitamin E  \
# i             t       m
# 1010101601002 2011-12 Tigray  1.310347  0.886001   0.265225   0.131576
# 1010101601017 2011-12 Tigray  1.210821  0.847072   0.245175   0.124396
# 1010101601034 2011-12 Tigray  3.032163  2.018431   1.333719   0.454529
# 1010101601049 2011-12 Tigray  2.626463  1.880298   0.938592   0.321365
# 1010101601064 2011-12 Tigray  1.348433  0.966431   0.536089   0.180680
# ...                                ...       ...        ...        ...
# 7210106202111 2011-12 SNNP    1.040630  0.943546   0.279637   0.245367
# 7210106202132 2011-12 SNNP    2.512957  1.971343   0.952008   0.472882
# 7210106202153 2011-12 SNNP    2.420857  1.552993   0.221385   0.253619
# 7210106202174 2011-12 SNNP    0.981211  0.905354   0.285187   0.236739
# 7210106202195 2011-12 SNNP    1.901144  1.624888   0.476587   0.386567
#
# n                             Vitamin C  Vitamin B-6  Vitamin B-12   Calcium  \
# i             t       m
# 1010101601002 2011-12 Tigray   0.122671     0.976634      0.819656  0.651046
# 1010101601017 2011-12 Tigray   0.102872     0.951404      0.762986  0.580121
# 1010101601034 2011-12 Tigray   0.298017     1.858395      3.814419  1.453096
# 1010101601049 2011-12 Tigray   0.260184     1.886321      2.779614  1.173402
# 1010101601064 2011-12 Tigray   0.117767     0.989263      1.683218  0.778538
# ...                                 ...          ...           ...       ...
# 7210106202111 2011-12 SNNP     0.211181     1.017547      0.942135  0.567244
# 7210106202132 2011-12 SNNP     0.318124     1.908674      3.110882  1.277862
# 7210106202153 2011-12 SNNP     0.243561     1.747733      0.637712  0.927124
# 7210106202174 2011-12 SNNP     0.180918     0.973980      0.915833  0.456376
# 7210106202195 2011-12 SNNP     0.329559     1.768740      1.515462  0.891492
#
# n                             Magnesium      Iron      Zinc     Fiber  Folate  \
# i             t       m
# 1010101601002 2011-12 Tigray   0.985070  1.461778  0.803603  0.319416     0.0
# 1010101601017 2011-12 Tigray   0.949062  1.306220  0.749866  0.301396     0.0
# 1010101601034 2011-12 Tigray   1.949842  4.258134  1.859290  0.644300     0.0
# 1010101601049 2011-12 Tigray   2.030124  2.836617  1.661981  0.624304     0.0
# 1010101601064 2011-12 Tigray   0.894910  1.360764  0.821282  0.292709     0.0
# ...                                 ...       ...       ...       ...     ...
# 7210106202111 2011-12 SNNP     0.854397  0.980245  0.660251  0.225816     0.0
# 7210106202132 2011-12 SNNP     1.767697  2.575238  1.499150  0.584044     0.0
# 7210106202153 2011-12 SNNP     1.831372  2.331646  1.410650  0.687051     0.0
# 7210106202174 2011-12 SNNP     0.861373  0.988922  0.658424  0.236241     0.0
# 7210106202195 2011-12 SNNP     1.598125  1.750525  1.212672  0.448485     0.0
#
# n                             Carbohydrate    Niacin  Phosphorus  Potassium  \
# i             t       m
# 1010101601002 2011-12 Tigray      0.566004  0.257457    0.475827   0.095171
# 1010101601017 2011-12 Tigray      0.514292  0.249289    0.416502   0.087725
# 1010101601034 2011-12 Tigray      1.014842  0.433356    1.105619   0.163899
# 1010101601049 2011-12 Tigray      1.044805  0.480470    0.817214   0.172406
# 1010101601064 2011-12 Tigray      0.518680  0.221486    0.405695   0.084669
# ...                                    ...       ...         ...        ...
# 7210106202111 2011-12 SNNP        0.392735  0.190368    0.329731   0.068269
# 7210106202132 2011-12 SNNP        1.034924  0.441932    0.893489   0.169547
# 7210106202153 2011-12 SNNP        1.246439  0.566965    1.047853   0.209584
# 7210106202174 2011-12 SNNP        0.403113  0.206564    0.376433   0.070612
# 7210106202195 2011-12 SNNP        0.724072  0.373163    0.756422   0.127817
#
# n                             Riboflavin   Thiamin  Vitamin K
# i             t       m
# 1010101601002 2011-12 Tigray    0.264117  0.392403   0.024331
# 1010101601017 2011-12 Tigray    0.259835  0.382019   0.023421
# 1010101601034 2011-12 Tigray    0.442810  0.639614   0.038085
# 1010101601049 2011-12 Tigray    0.501472  0.724349   0.047052
# 1010101601064 2011-12 Tigray    0.231581  0.342470   0.020311
# ...                                  ...       ...        ...
# 7210106202111 2011-12 SNNP      0.195000  0.291726   0.019412
# 7210106202132 2011-12 SNNP      0.451572  0.672655   0.038839
# 7210106202153 2011-12 SNNP      0.589824  0.876662   0.050809
# 7210106202174 2011-12 SNNP      0.214979  0.316384   0.018566
# 7210106202195 2011-12 SNNP      0.386145  0.570442   0.032179
#
# [3129 rows x 20 columns]

# %% [markdown]
# Graph ratios of adequacy for particular nutrients

# %%
import matplotlib.pyplot as plt

selected_nutrients = ['Vitamin A', 'Vitamin E', 'Zinc', 'Energy', 'Protein', 'Vitamin C']
nutrient_means = nutrient_ratio[selected_nutrients].mean()
nutrient_means.plot(kind='bar')
plt.title('Average Nutrient Ratios')
plt.ylabel('Ratio')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout
plt.show()
